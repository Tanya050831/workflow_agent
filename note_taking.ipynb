# %% [markdown]
# python学习中的两个查找函数

# %%
# 🔍 Kernel 共享检查工具
# 运行这个cell来检查当前notebook的kernel信息

import sys
import os

print("=" * 60)
print("📊 当前 Kernel 信息")
print("=" * 60)
print(f"Python 版本: {sys.version}")
print(f"Python 路径: {sys.executable}")
print(f"Kernel 进程 ID: {os.getpid()}")
print(f"\n已导入的模块数量: {len(sys.modules)}")

# 检查 torch 是否已导入
if 'torch' in sys.modules:
    torch = sys.modules['torch']
    print(f"\n✅ torch 已导入")
    print(f"   - torch 对象内存地址: {id(torch)}")
    print(f"   - torch 版本: {torch.__version__}")
else:
    print(f"\n❌ torch 未导入")

print("\n" + "=" * 60)
print("💡 如何检查是否共享 kernel:")
print("=" * 60)
print("1. 在另一个 notebook 中运行相同的代码")
print("2. 比较 'Kernel 进程 ID' - 如果相同，说明共享kernel")
print("3. 比较 'torch 对象内存地址' - 如果相同，说明共享kernel")
print("4. 或者：在一个notebook中设置变量，在另一个中访问")
print("=" * 60)
# Out:
# ...
# 📊 当前 Kernel 信息
# ...
# Python 版本: 3.13.5 | packaged by Anaconda, Inc. | (main, Jun 12 2025, 11:23:37) [Clang 14.0.6 ]
# Python 路径: /opt/anaconda3/bin/python
# Kernel 进程 ID: 63766
#
# 已导入的模块数量: 1893
#
# ✅ torch 已导入
#    - torch 对象内存地址: 4592838640
#    - torch 版本: 2.7.1
#
# ...
# 💡 如何检查是否共享 kernel:
# ...
# 1. 在另一个 notebook 中运行相同的代码
# 2. 比较 'Kernel 进程 ID' - 如果相同，说明共享kernel
# 3. 比较 'torch 对象内存地址' - 如果相同，说明共享kernel
# 4. 或者：在一个notebook中设置变量，在另一个中访问
# ...

# %%
# 🧪 简单测试：设置一个测试变量
# 如果其他notebook能访问这个变量，说明共享kernel
# 如果访问不到，说明是独立的kernel进程

TEST_SHARED_VAR = f"来自 note_taking.ipynb, 进程ID: {os.getpid()}"
print(f"✅ 已设置测试变量: {TEST_SHARED_VAR}")
print("\n💡 现在去其他notebook运行以下代码来测试:")
print("   try:")
print("       print(TEST_SHARED_VAR)")
print("       print('✅ 共享kernel！')")
print("   except NameError:")
print("       print('❌ 独立kernel，变量不存在')")

# %%
import torch
dir() #打开,探索
dir(torch)
help()#说明书
# Out:
# Welcome to Python 3.13's help utility! If this is your first time using
# Python, you should definitely check out the tutorial at
# https://docs.python.org/3.13/tutorial/.
#
# Enter the name of any module, keyword, or topic to get help on writing
# Python programs and using Python modules.  To get a list of available
# modules, keywords, symbols, or topics, enter "modules", "keywords",
# "symbols", or "topics".
#
# Each module also comes with a one-line summary of what it does; to list
# the modules whose name or summary contain a given string such as "spam",
# enter "modules spam".
#
# To quit this help utility and return to the interpreter,
# enter "q", "quit" or "exit".
#
#
# You are now leaving help and returning to the Python interpreter.
# If you want to ask for help on a particular object directly from the
# interpreter, you can type "help(object)".  Executing "help('string')"
# has the same effect as typing a particular string at the help> prompt.
